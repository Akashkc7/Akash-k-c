# %% [markdown]
# <a href="https://colab.research.google.com/github/Akashkc7/Akash-k-c/blob/main/TITANIC_SURVIVAL_PREDICTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **TITANIC SURVIVAL PREDICTION**

# %%
#importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing Data
data = pd.read_csv('/content/tested.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# **Exploratory Data Analysis(EDA)**

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# **Summary Statistics**

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.shape
# Out:
# (418, 12)

# %% [markdown]
# **Data Preprocessing**

# %%
data.isnull()
# Out:
#      Survived  Pclass    Sex    Age  SibSp  Parch   Fare  Cabin  Embarked
# 0       False   False  False  False  False  False  False   True     False
# 1       False   False  False  False  False  False  False   True     False
# 2       False   False  False  False  False  False  False   True     False
# 3       False   False  False  False  False  False  False   True     False
# 4       False   False  False  False  False  False  False   True     False
# ..        ...     ...    ...    ...    ...    ...    ...    ...       ...
# 413     False   False  False   True  False  False  False   True     False
# 414     False   False  False  False  False  False  False  False     False
# 415     False   False  False  False  False  False  False   True     False
# 416     False   False  False   True  False  False  False   True     False
# 417     False   False  False   True  False  False  False   True     False
#
# [418 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age          86
# SibSp         0
# Parch         0
# Fare          1
# Cabin       327
# Embarked      0
# dtype: int64

# %% [markdown]
# *   **Cabin contain 327 missing data so removing the cabin column will be
#       efficient**
# *   **Age contains 86 missing value.Age cannot be removed as it is important
#   for the model so it is filled with mean.**
# *   **Fare has 1 missing value.it can be filled with mean**

# %%
data = df.drop(['PassengerId','Name','Cabin','Ticket'], axis =1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-242-53e1d176a4d1> in <cell line: 1>()
# ----> 1 data = data.drop(['Cabin'],axis=1)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
data['Fare'].fillna(data['Fare'].mean(),inplace=True)

# %%
mean_age = np.random.randint(data['Age'].mean() - data['Age'].std(), data['Age'].mean() + data['Age'].std(), 86)

# %%
data['Age'][data['Age'].isnull()] = mean_age
# Out:
# <ipython-input-202-d4ddd61f9d4a>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Age'][data['Age'].isnull()] = mean_age

# %%
data
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0           0       3    male  34.5      0      0    7.8292        Q
# 1           1       3  female  47.0      1      0    7.0000        S
# 2           0       2    male  62.0      0      0    9.6875        Q
# 3           0       3    male  27.0      0      0    8.6625        S
# 4           1       3  female  22.0      1      1   12.2875        S
# ..        ...     ...     ...   ...    ...    ...       ...      ...
# 413         0       3    male  17.0      0      0    8.0500        S
# 414         1       1  female  39.0      0      0  108.9000        C
# 415         0       3    male  38.5      0      0    7.2500        S
# 416         0       3    male  24.0      0      0    8.0500        S
# 417         0       3    male  17.0      1      1   22.3583        C
#
# [418 rows x 8 columns]

# %%
data.isna().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %% [markdown]
# **Data Visualisation**

# %%
def make_piechart(data, target_feature, additional=''):
    # Count the occurrences of each category in the target feature
    value_counts = data[target_feature].value_counts()

    # Extracting the categories and their counts
    categories = value_counts.index
    counts = value_counts.values

    palette_color = sns.color_palette('bright')
    plt.pie(counts, labels=categories, colors=palette_color, autopct='%.0f%%', startangle=140)
    plt.title(f"Distribution of Passenger's {target_feature} {additional}")
    plt.show()

    # Preparing a text summary of the distribution
    summary = f"Distribution of Passenger's {target_feature.lower()} {additional}:\n"
    for category, count in zip(categories, counts):
        summary += f"{category}: {count}\n"

    print(summary)

# %%
make_piechart(data,'Sex')
# Out:
# Distribution of Passenger's sex :
# male: 266
# female: 152

# %% [markdown]
# *   **There are more male passengers**

# %%
make_piechart(data,'Survived')
# Out:
# Distribution of Passenger's survived :
# 0: 266
# 1: 152

# %%
make_piechart(data,'Pclass')
# Out:
# Distribution of Passenger's pclass :
# 3: 218
# 1: 107
# 2: 93

# %% [markdown]
# *   **152 Passengers were survived**

# %%
#plotting histogram for age distribution
plt.hist(data['Age'],bins=20)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.ylabel("Frequency")
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
sns.histplot(data=data, x='Fare',color='grey')
plt.title('Distribution of Fare In Titanic')
plt.xlabel('Fare')
plt.ylabel("Frequency")
plt.tight_layout()
plt.show()

# %%
numerical_columns= ['Age','SibSp','Parch','Fare']
con_matr= data[numerical_columns].corr()

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(con_matr,annot=True, cmap='viridis', linewidths=0.5)
plt.title('Correlation Heatmap of Numerical Columns')
plt.show()

# %%
sns.countplot(data=data, x='Pclass',hue='Survived', palette='viridis')
# Out:
# <Axes: xlabel='Pclass', ylabel='count'>

# %%
# Boxplot of Age by Pclass
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Survived', y='Age', palette='viridis')
plt.xlabel('Pclass')
plt.ylabel('Age')
plt.title('Distribution of Age by Survived')
plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler,LabelEncoder,FunctionTransformer
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,GridSearchCV
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_score,recall_score,f1_score

# %% [markdown]
# **Encoding**

# %%
se=LabelEncoder()
em=LabelEncoder()

# %%
data['Sex']=se.fit_transform(data['Sex'])
data['Embarked']=em.fit_transform(data['Embarked'])

# %%
data
# Out:
#      Survived  Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0           0       3    1  34.5      0      0    7.8292         1
# 1           1       3    0  47.0      1      0    7.0000         2
# 2           0       2    1  62.0      0      0    9.6875         1
# 3           0       3    1  27.0      0      0    8.6625         2
# 4           1       3    0  22.0      1      1   12.2875         2
# ..        ...     ...  ...   ...    ...    ...       ...       ...
# 413         0       3    1  17.0      0      0    8.0500         2
# 414         1       1    0  39.0      0      0  108.9000         0
# 415         0       3    1  38.5      0      0    7.2500         2
# 416         0       3    1  24.0      0      0    8.0500         2
# 417         0       3    1  17.0      1      1   22.3583         0
#
# [418 rows x 8 columns]

# %% [markdown]
# **SPLITTING DATA INTO INPUT AND OUTPUT LABELS**

# %%
x=data.drop(['Survived'],axis=1)
y=data['Survived']

# %%
x
# Out:
#      Pclass  Sex   Age  SibSp  Parch      Fare  Embarked
# 0         3    1  34.5      0      0    7.8292         1
# 1         3    0  47.0      1      0    7.0000         2
# 2         2    1  62.0      0      0    9.6875         1
# 3         3    1  27.0      0      0    8.6625         2
# 4         3    0  22.0      1      1   12.2875         2
# ..      ...  ...   ...    ...    ...       ...       ...
# 413       3    1  17.0      0      0    8.0500         2
# 414       1    0  39.0      0      0  108.9000         0
# 415       3    1  38.5      0      0    7.2500         2
# 416       3    1  24.0      0      0    8.0500         2
# 417       3    1  17.0      1      1   22.3583         0
#
# [418 rows x 7 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=42)

# %% [markdown]
# **FEATURE SCALING**

# %%
scaler= StandardScaler()
x_train=scaler.fit_transform(x_train)
x_test = scaler.transform(x_test)
x_train
# Out:
# array([[-1.47596812,  0.78310898,  0.41024775, ..., -0.43509701,
#          0.60029624, -1.59128384],
#        [ 0.8727114 ,  0.78310898,  0.26425655, ..., -0.43509701,
#         -0.51006323, -0.43542593],
#        [-1.47596812, -1.27696148,  2.38112882, ..., -0.43509701,
#          3.01110083,  0.72043199],
#        ...,
#        [-1.47596812,  0.78310898,  1.1402037 , ..., -0.43509701,
#          0.60029624, -1.59128384],
#        [-0.30162836,  0.78310898, -0.4656994 , ..., -0.43509701,
#         -0.41546542,  0.72043199],
#        [ 0.8727114 ,  0.78310898, -0.4656994 , ..., -0.43509701,
#         -0.51006323, -0.43542593]])

# %% [markdown]
# **MODEL CREATION**

# %% [markdown]
# **Random Forest Classifier Model**

# %%
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred1=rf.predict(x_test)

# %%
print(accuracy_score(y_test,y_pred1)*100)
print(classification_report(y_test,y_pred1))
# Out:
# 100.0
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        85
#            1       1.00      1.00      1.00        41
#
#     accuracy                           1.00       126
#    macro avg       1.00      1.00      1.00       126
# weighted avg       1.00      1.00      1.00       126

# %%
cm = confusion_matrix(y_test, y_pred1)
plt.figure(figsize=(8, 6))
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', cbar=False)
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.title('Confusion Matrix')
plt.show()
